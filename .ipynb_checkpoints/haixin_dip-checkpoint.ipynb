# %% [markdown]
# # Image Edge Detection - Scharr and Canny Operators
#
# This notebook processes all JPG images in a folder using Scharr and Canny edge detection operators.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import cv2
import numpy as np
import os
from pathlib import Path
import matplotlib.pyplot as plt

# Set matplotlib to display images properly
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ## 2. Set Input and Output Paths

# %%
# Input folder path (folder containing JPG images)
input_folder = 'images'  # Change this to your input folder path

# Output folder paths
output_folder_scharr = 'haixin_output_scharr'
output_folder_canny = 'haixin_output_canny'

# Create output folders
os.makedirs(output_folder_scharr, exist_ok=True)
os.makedirs(output_folder_canny, exist_ok=True)

print(f"Input folder: {input_folder}")
print(f"Scharr output folder: {output_folder_scharr}")
print(f"Canny output folder: {output_folder_canny}")
# Out:
# Input folder: car_plates/images
# Scharr output folder: haixin_output_scharr
# Canny output folder: haixin_output_canny

# %% [markdown]
# ## 3. Define Edge Detection Functions

# %%
def apply_scharr(image):
    """
    Apply Scharr operator for edge detection
    
    Args:
        image: Input image
    
    Returns:
        Edge-detected image
    """
    # Convert to grayscale
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    
    # Apply Scharr operator (x and y directions)
    scharr_x = cv2.Scharr(gray, cv2.CV_64F, 1, 0)
    scharr_y = cv2.Scharr(gray, cv2.CV_64F, 0, 1)
    
    # Calculate gradient magnitude
    scharr_x = cv2.convertScaleAbs(scharr_x)
    scharr_y = cv2.convertScaleAbs(scharr_y)
    scharr = cv2.addWeighted(scharr_x, 0.5, scharr_y, 0.5, 0)
    
    return scharr


def apply_canny(image, threshold1=50, threshold2=150):
    """
    Apply Canny operator for edge detection
    
    Args:
        image: Input image
        threshold1: First threshold (low threshold)
        threshold2: Second threshold (high threshold)
    
    Returns:
        Edge-detected image
    """
    # Convert to grayscale
    if len(image.shape) == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    
    # Gaussian blur to reduce noise
    blurred = cv2.GaussianBlur(gray, (5, 5), 1.4)
    
    # Apply Canny operator
    canny = cv2.Canny(blurred, threshold1, threshold2)
    
    return canny

# %% [markdown]
# ## 4. Batch Process Images

# %%
# Get all JPG files
jpg_files = list(Path(input_folder).glob('*.jpg')) + list(Path(input_folder).glob('*.JPG'))

print(f"Found {len(jpg_files)} JPG files")
print("\nStarting processing...\n")

# Process each image file
for i, img_path in enumerate(jpg_files, 1):
    try:
        # Read image
        image = cv2.imread(str(img_path))
        
        if image is None:
            print(f"[{i}/{len(jpg_files)}] Cannot read: {img_path.name}")
            continue
        
        # Apply Scharr operator
        scharr_result = apply_scharr(image)
        scharr_output_path = os.path.join(output_folder_scharr, img_path.name)
        cv2.imwrite(scharr_output_path, scharr_result)
        
        # Apply Canny operator
        canny_result = apply_canny(image)
        canny_output_path = os.path.join(output_folder_canny, img_path.name)
        cv2.imwrite(canny_output_path, canny_result)
        
        print(f"[{i}/{len(jpg_files)}] Processed: {img_path.name}")
        
    except Exception as e:
        print(f"[{i}/{len(jpg_files)}] Error processing {img_path.name}: {str(e)}")

print("\nAll images processed successfully!")
# Out:
# Found 201 JPG files
#
# Starting processing...
#
# [1/201] Processed: alpr_lp_61.jpg
# [2/201] Processed: alpr_lp_167.jpg
# [3/201] Processed: alpr_lp_160.jpg
# [4/201] Processed: alpr_lp_66.jpg
# [5/201] Processed: alpr_lp_14.jpg
# [6/201] Processed: alpr_lp_68.jpg
# [7/201] Processed: alpr_lp_112.jpg
# [8/201] Processed: alpr_lp_115.jpg
# [9/201] Processed: alpr_lp_13.jpg
# [10/201] Processed: alpr_lp_169.jpg
# [11/201] Processed: alpr_lp_120.jpg
# [12/201] Processed: alpr_lp_26.jpg
# [13/201] Processed: alpr_lp_21.jpg
# [14/201] Processed: alpr_lp_127.jpg
# [15/201] Processed: alpr_lp_184.jpg
# [16/201] Processed: alpr_lp_155.jpg
# [17/201] Processed: alpr_lp_82.jpg
# [18/201] Processed: alpr_lp_129.jpg
# [19/201] Processed: alpr_lp_53.jpg
# [20/201] Processed: alpr_lp_85.jpg
# [21/201] Processed: alpr_lp_54.jpg
# [22/201] Processed: alpr_lp_183.jpg
# [23/201] Processed: alpr_lp_152.jpg
# [24/201] Processed: alpr_lp_28.jpg
# [25/201] Processed: alpr_lp_45.jpg
# [26/201] Processed: alpr_lp_94.jpg
# [27/201] Processed: alpr_lp_39.jpg
# [28/201] Processed: alpr_lp_143.jpg
# [29/201] Processed: alpr_lp_192.jpg
# [30/201] Processed: alpr_lp_144.jpg
# [31/201] Processed: alpr_lp_195.jpg
# [32/201] Processed: alpr_lp_42.jpg
# [33/201] Processed: alpr_lp_138.jpg
# [34/201] Processed: alpr_lp_93.jpg
# [35/201] Processed: alpr_lp_30.jpg
# [36/201] Processed: alpr_lp_136.jpg
# [37/201] Processed: alpr_lp_131.jpg
# [38/201] Processed: alpr_lp_37.jpg
# [39/201] Processed: alpr_lp_104.jpg
# [40/201] Processed: alpr_lp_7.jpg
# [41/201] Processed: alpr_lp_178.jpg
# [42/201] Processed: alpr_lp_103.jpg
# [43/201] Processed: alpr_lp_79.jpg
# [44/201] Processed: alpr_lp_171.jpg
# [45/201] Processed: alpr_lp_77.jpg
# [46/201] Processed: alpr_lp_70.jpg
# [47/201] Processed: alpr_lp_9.jpg
# [48/201] Processed: alpr_lp_176.jpg
# [49/201] Processed: alpr_lp_84.jpg
# [50/201] Processed: alpr_lp_55.jpg
# [51/201] Processed: alpr_lp_182.jpg
# [52/201] Processed: alpr_lp_29.jpg
# [53/201] Processed: alpr_lp_153.jpg
# [54/201] Processed: alpr_lp_185.jpg
# [55/201] Processed: alpr_lp_154.jpg
# [56/201] Processed: alpr_lp_83.jpg
# [57/201] Processed: alpr_lp_52.jpg
# [58/201] Processed: alpr_lp_128.jpg
# [59/201] Processed: alpr_lp_20.jpg
# [60/201] Processed: alpr_lp_126.jpg
# [61/201] Processed: alpr_lp_121.jpg
# [62/201] Processed: alpr_lp_27.jpg
# [63/201] Processed: alpr_lp_114.jpg
# [64/201] Processed: alpr_lp_168.jpg
# [65/201] Processed: alpr_lp_12.jpg
# [66/201] Processed: alpr_lp_15.jpg
# [67/201] Processed: alpr_lp_113.jpg
# [68/201] Processed: alpr_lp_69.jpg
# [69/201] Processed: alpr_lp_161.jpg
# [70/201] Processed: alpr_lp_67.jpg
# [71/201] Processed: alpr_lp_60.jpg
# [72/201] Processed: alpr_lp_166.jpg
# [73/201] Processed: alpr_lp_71.jpg
# [74/201] Processed: alpr_lp_8.jpg
# [75/201] Processed: alpr_lp_177.jpg
# [76/201] Processed: alpr_lp_170.jpg
# [77/201] Processed: alpr_lp_76.jpg
# [78/201] Processed: alpr_lp_78.jpg
# [79/201] Processed: alpr_lp_102.jpg
# [80/201] Processed: alpr_lp_1.jpg
# [81/201] Processed: alpr_lp_105.jpg
# [82/201] Processed: alpr_lp_6.jpg
# [83/201] Processed: alpr_lp_179.jpg
# [84/201] Processed: alpr_lp_130.jpg
# [85/201] Processed: alpr_lp_36.jpg
# [86/201] Processed: alpr_lp_31.jpg
# [87/201] Processed: alpr_lp_137.jpg
# [88/201] Processed: alpr_lp_145.jpg
# [89/201] Processed: alpr_lp_194.jpg
# [90/201] Processed: alpr_lp_139.jpg
# [91/201] Processed: alpr_lp_43.jpg
# [92/201] Processed: alpr_lp_92.jpg
# [93/201] Processed: alpr_lp_44.jpg
# [94/201] Processed: alpr_lp_95.jpg
# [95/201] Processed: alpr_lp_142.jpg
# [96/201] Processed: alpr_lp_38.jpg
# [97/201] Processed: alpr_lp_193.jpg
# [98/201] Processed: alpr_lp_173.jpg
# [99/201] Processed: alpr_lp_75.jpg
# [100/201] Processed: alpr_lp_108.jpg
# [101/201] Processed: alpr_lp_72.jpg
# [102/201] Processed: alpr_lp_174.jpg
# [103/201] Processed: alpr_lp_106.jpg
# [104/201] Processed: alpr_lp_5.jpg
# [105/201] Processed: alpr_lp_101.jpg
# [106/201] Processed: alpr_lp_2.jpg
# [107/201] Processed: alpr_lp_32.jpg
# [108/201] Processed: alpr_lp_148.jpg
# [109/201] Processed: alpr_lp_199.jpg
# [110/201] Processed: alpr_lp_134.jpg
# [111/201] Processed: alpr_lp_49.jpg
# [112/201] Processed: alpr_lp_133.jpg
# [113/201] Processed: alpr_lp_98.jpg
# [114/201] Processed: alpr_lp_35.jpg
# [115/201] Processed: alpr_lp_47.jpg
# [116/201] Processed: alpr_lp_96.jpg
# [117/201] Processed: alpr_lp_141.jpg
# [118/201] Processed: alpr_lp_190.jpg
# [119/201] Processed: alpr_lp_146.jpg
# [120/201] Processed: alpr_lp_197.jpg
# [121/201] Processed: alpr_lp_40.jpg
# [122/201] Processed: alpr_lp_91.jpg
# [123/201] Processed: alpr_lp_186.jpg
# [124/201] Processed: alpr_lp_157.jpg
# [125/201] Processed: alpr_lp_80.jpg
# [126/201] Processed: alpr_lp_51.jpg
# [127/201] Processed: alpr_lp_87.jpg
# [128/201] Processed: alpr_lp_56.jpg
# [129/201] Processed: alpr_lp_181.jpg
# [130/201] Processed: alpr_lp_150.jpg
# [131/201] Processed: alpr_lp_89.jpg
# [132/201] Processed: alpr_lp_122.jpg
# [133/201] Processed: alpr_lp_58.jpg
# [134/201] Processed: alpr_lp_24.jpg
# [135/201] Processed: alpr_lp_188.jpg
# [136/201] Processed: alpr_lp_159.jpg
# [137/201] Processed: alpr_lp_23.jpg
# [138/201] Processed: alpr_lp_125.jpg
# [139/201] Processed: alpr_lp_16.jpg
# [140/201] Processed: alpr_lp_110.jpg
# [141/201] Processed: alpr_lp_117.jpg
# [142/201] Processed: alpr_lp_200.jpg
# [143/201] Processed: alpr_lp_11.jpg
# [144/201] Processed: alpr_lp_63.jpg
# [145/201] Processed: alpr_lp_119.jpg
# [146/201] Processed: alpr_lp_165.jpg
# [147/201] Processed: alpr_lp_18.jpg
# [148/201] Processed: alpr_lp_162.jpg
# [149/201] Processed: alpr_lp_64.jpg
# [150/201] Processed: alpr_lp_147.jpg
# [151/201] Processed: alpr_lp_196.jpg
# [152/201] Processed: alpr_lp_41.jpg
# [153/201] Processed: alpr_lp_90.jpg
# [154/201] Processed: alpr_lp_46.jpg
# [155/201] Processed: alpr_lp_97.jpg
# [156/201] Processed: alpr_lp_140.jpg
# [157/201] Processed: alpr_lp_191.jpg
# [158/201] Processed: alpr_lp_132.jpg
# [159/201] Processed: alpr_lp_48.jpg
# [160/201] Processed: alpr_lp_99.jpg
# [161/201] Processed: alpr_lp_34.jpg
# [162/201] Processed: alpr_lp_149.jpg
# [163/201] Processed: alpr_lp_33.jpg
# [164/201] Processed: alpr_lp_198.jpg
# [165/201] Processed: alpr_lp_135.jpg
# [166/201] Processed: alpr_lp_100.jpg
# [167/201] Processed: alpr_lp_3.jpg
# [168/201] Processed: alpr_lp_107.jpg
# [169/201] Processed: alpr_lp_4.jpg
# [170/201] Processed: alpr_lp_73.jpg
# [171/201] Processed: alpr_lp_109.jpg
# [172/201] Processed: alpr_lp_175.jpg
# [173/201] Processed: alpr_lp_172.jpg
# [174/201] Processed: alpr_lp_74.jpg
# [175/201] Processed: alpr_lp_163.jpg
# [176/201] Processed: alpr_lp_19.jpg
# [177/201] Processed: alpr_lp_65.jpg
# [178/201] Processed: alpr_lp_118.jpg
# [179/201] Processed: alpr_lp_62.jpg
# [180/201] Processed: alpr_lp_164.jpg
# [181/201] Processed: alpr_lp_116.jpg
# [182/201] Processed: alpr_lp_201.jpg
# [183/201] Processed: alpr_lp_10.jpg
# [184/201] Processed: alpr_lp_17.jpg
# [185/201] Processed: alpr_lp_111.jpg
# [186/201] Processed: alpr_lp_189.jpg
# [187/201] Processed: alpr_lp_22.jpg
# [188/201] Processed: alpr_lp_158.jpg
# [189/201] Processed: alpr_lp_124.jpg
# [190/201] Processed: alpr_lp_88.jpg
# [191/201] Processed: alpr_lp_59.jpg
# [192/201] Processed: alpr_lp_123.jpg
# [193/201] Processed: alpr_lp_25.jpg
# [194/201] Processed: alpr_lp_86.jpg
# [195/201] Processed: alpr_lp_57.jpg
# [196/201] Processed: alpr_lp_180.jpg
# [197/201] Processed: alpr_lp_151.jpg
# [198/201] Processed: alpr_lp_187.jpg
# [199/201] Processed: alpr_lp_156.jpg
# [200/201] Processed: alpr_lp_81.jpg
# [201/201] Processed: alpr_lp_50.jpg
#
# All images processed successfully!

# %% [markdown]
# ## 5. Visualization Comparison (Optional)
#
# Display comparison results for the first image

# %%
if len(jpg_files) > 0:
    # Read the first image
    sample_img_path = jpg_files[0]
    sample_image = cv2.imread(str(sample_img_path))
    sample_image_rgb = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
    
    # Apply both operators
    scharr_result = apply_scharr(sample_image)
    canny_result = apply_canny(sample_image)
    
    # Visualize
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    
    axes[0].imshow(sample_image_rgb)
    axes[0].set_title('Original Image', fontsize=14)
    axes[0].axis('off')
    
    axes[1].imshow(scharr_result, cmap='gray')
    axes[1].set_title('Scharr Operator Result', fontsize=14)
    axes[1].axis('off')
    
    axes[2].imshow(canny_result, cmap='gray')
    axes[2].set_title('Canny Operator Result', fontsize=14)
    axes[2].axis('off')
    
    plt.tight_layout()
    plt.show()
    
    print(f"\nSample image: {sample_img_path.name}")
else:
    print("No image files found for visualization")
# Out:
# Sample image: alpr_lp_61.jpg

# %% [markdown]
# ## 6. Adjust Canny Parameters (Optional)
#
# If Canny results are not ideal, you can adjust threshold parameters and reprocess

# %%
# Custom Canny thresholds
custom_threshold1 = 30   # Low threshold
custom_threshold2 = 100  # High threshold

# Create new output folder
output_folder_canny_custom = 'output_canny_custom'
os.makedirs(output_folder_canny_custom, exist_ok=True)

print(f"Reprocessing with custom thresholds: threshold1={custom_threshold1}, threshold2={custom_threshold2}\n")

for i, img_path in enumerate(jpg_files, 1):
    try:
        image = cv2.imread(str(img_path))
        if image is None:
            continue
        
        canny_result = apply_canny(image, custom_threshold1, custom_threshold2)
        output_path = os.path.join(output_folder_canny_custom, img_path.name)
        cv2.imwrite(output_path, canny_result)
        
        print(f"[{i}/{len(jpg_files)}] Processed: {img_path.name}")
    except Exception as e:
        print(f"[{i}/{len(jpg_files)}] Error processing: {str(e)}")

print("\nCustom parameter processing complete!")
# Out:
# Reprocessing with custom thresholds: threshold1=30, threshold2=100
#
# [1/201] Processed: alpr_lp_61.jpg
# [2/201] Processed: alpr_lp_167.jpg
# [3/201] Processed: alpr_lp_160.jpg
# [4/201] Processed: alpr_lp_66.jpg
# [5/201] Processed: alpr_lp_14.jpg
# [6/201] Processed: alpr_lp_68.jpg
# [7/201] Processed: alpr_lp_112.jpg
# [8/201] Processed: alpr_lp_115.jpg
# [9/201] Processed: alpr_lp_13.jpg
# [10/201] Processed: alpr_lp_169.jpg
# [11/201] Processed: alpr_lp_120.jpg
# [12/201] Processed: alpr_lp_26.jpg
# [13/201] Processed: alpr_lp_21.jpg
# [14/201] Processed: alpr_lp_127.jpg
# [15/201] Processed: alpr_lp_184.jpg
# [16/201] Processed: alpr_lp_155.jpg
# [17/201] Processed: alpr_lp_82.jpg
# [18/201] Processed: alpr_lp_129.jpg
# [19/201] Processed: alpr_lp_53.jpg
# [20/201] Processed: alpr_lp_85.jpg
# [21/201] Processed: alpr_lp_54.jpg
# [22/201] Processed: alpr_lp_183.jpg
# [23/201] Processed: alpr_lp_152.jpg
# [24/201] Processed: alpr_lp_28.jpg
# [25/201] Processed: alpr_lp_45.jpg
# [26/201] Processed: alpr_lp_94.jpg
# [27/201] Processed: alpr_lp_39.jpg
# [28/201] Processed: alpr_lp_143.jpg
# [29/201] Processed: alpr_lp_192.jpg
# [30/201] Processed: alpr_lp_144.jpg
# [31/201] Processed: alpr_lp_195.jpg
# [32/201] Processed: alpr_lp_42.jpg
# [33/201] Processed: alpr_lp_138.jpg
# [34/201] Processed: alpr_lp_93.jpg
# [35/201] Processed: alpr_lp_30.jpg
# [36/201] Processed: alpr_lp_136.jpg
# [37/201] Processed: alpr_lp_131.jpg
# [38/201] Processed: alpr_lp_37.jpg
# [39/201] Processed: alpr_lp_104.jpg
# [40/201] Processed: alpr_lp_7.jpg
# [41/201] Processed: alpr_lp_178.jpg
# [42/201] Processed: alpr_lp_103.jpg
# [43/201] Processed: alpr_lp_79.jpg
# [44/201] Processed: alpr_lp_171.jpg
# [45/201] Processed: alpr_lp_77.jpg
# [46/201] Processed: alpr_lp_70.jpg
# [47/201] Processed: alpr_lp_9.jpg
# [48/201] Processed: alpr_lp_176.jpg
# [49/201] Processed: alpr_lp_84.jpg
# [50/201] Processed: alpr_lp_55.jpg
# [51/201] Processed: alpr_lp_182.jpg
# [52/201] Processed: alpr_lp_29.jpg
# [53/201] Processed: alpr_lp_153.jpg
# [54/201] Processed: alpr_lp_185.jpg
# [55/201] Processed: alpr_lp_154.jpg
# [56/201] Processed: alpr_lp_83.jpg
# [57/201] Processed: alpr_lp_52.jpg
# [58/201] Processed: alpr_lp_128.jpg
# [59/201] Processed: alpr_lp_20.jpg
# [60/201] Processed: alpr_lp_126.jpg
# [61/201] Processed: alpr_lp_121.jpg
# [62/201] Processed: alpr_lp_27.jpg
# [63/201] Processed: alpr_lp_114.jpg
# [64/201] Processed: alpr_lp_168.jpg
# [65/201] Processed: alpr_lp_12.jpg
# [66/201] Processed: alpr_lp_15.jpg
# [67/201] Processed: alpr_lp_113.jpg
# [68/201] Processed: alpr_lp_69.jpg
# [69/201] Processed: alpr_lp_161.jpg
# [70/201] Processed: alpr_lp_67.jpg
# [71/201] Processed: alpr_lp_60.jpg
# [72/201] Processed: alpr_lp_166.jpg
# [73/201] Processed: alpr_lp_71.jpg
# [74/201] Processed: alpr_lp_8.jpg
# [75/201] Processed: alpr_lp_177.jpg
# [76/201] Processed: alpr_lp_170.jpg
# [77/201] Processed: alpr_lp_76.jpg
# [78/201] Processed: alpr_lp_78.jpg
# [79/201] Processed: alpr_lp_102.jpg
# [80/201] Processed: alpr_lp_1.jpg
# [81/201] Processed: alpr_lp_105.jpg
# [82/201] Processed: alpr_lp_6.jpg
# [83/201] Processed: alpr_lp_179.jpg
# [84/201] Processed: alpr_lp_130.jpg
# [85/201] Processed: alpr_lp_36.jpg
# [86/201] Processed: alpr_lp_31.jpg
# [87/201] Processed: alpr_lp_137.jpg
# [88/201] Processed: alpr_lp_145.jpg
# [89/201] Processed: alpr_lp_194.jpg
# [90/201] Processed: alpr_lp_139.jpg
# [91/201] Processed: alpr_lp_43.jpg
# [92/201] Processed: alpr_lp_92.jpg
# [93/201] Processed: alpr_lp_44.jpg
# [94/201] Processed: alpr_lp_95.jpg
# [95/201] Processed: alpr_lp_142.jpg
# [96/201] Processed: alpr_lp_38.jpg
# [97/201] Processed: alpr_lp_193.jpg
# [98/201] Processed: alpr_lp_173.jpg
# [99/201] Processed: alpr_lp_75.jpg
# [100/201] Processed: alpr_lp_108.jpg
# [101/201] Processed: alpr_lp_72.jpg
# [102/201] Processed: alpr_lp_174.jpg
# [103/201] Processed: alpr_lp_106.jpg
# [104/201] Processed: alpr_lp_5.jpg
# [105/201] Processed: alpr_lp_101.jpg
# [106/201] Processed: alpr_lp_2.jpg
# [107/201] Processed: alpr_lp_32.jpg
# [108/201] Processed: alpr_lp_148.jpg
# [109/201] Processed: alpr_lp_199.jpg
# [110/201] Processed: alpr_lp_134.jpg
# [111/201] Processed: alpr_lp_49.jpg
# [112/201] Processed: alpr_lp_133.jpg
# [113/201] Processed: alpr_lp_98.jpg
# [114/201] Processed: alpr_lp_35.jpg
# [115/201] Processed: alpr_lp_47.jpg
# [116/201] Processed: alpr_lp_96.jpg
# [117/201] Processed: alpr_lp_141.jpg
# [118/201] Processed: alpr_lp_190.jpg
# [119/201] Processed: alpr_lp_146.jpg
# [120/201] Processed: alpr_lp_197.jpg
# [121/201] Processed: alpr_lp_40.jpg
# [122/201] Processed: alpr_lp_91.jpg
# [123/201] Processed: alpr_lp_186.jpg
# [124/201] Processed: alpr_lp_157.jpg
# [125/201] Processed: alpr_lp_80.jpg
# [126/201] Processed: alpr_lp_51.jpg
# [127/201] Processed: alpr_lp_87.jpg
# [128/201] Processed: alpr_lp_56.jpg
# [129/201] Processed: alpr_lp_181.jpg
# [130/201] Processed: alpr_lp_150.jpg
# [131/201] Processed: alpr_lp_89.jpg
# [132/201] Processed: alpr_lp_122.jpg
# [133/201] Processed: alpr_lp_58.jpg
# [134/201] Processed: alpr_lp_24.jpg
# [135/201] Processed: alpr_lp_188.jpg
# [136/201] Processed: alpr_lp_159.jpg
# [137/201] Processed: alpr_lp_23.jpg
# [138/201] Processed: alpr_lp_125.jpg
# [139/201] Processed: alpr_lp_16.jpg
# [140/201] Processed: alpr_lp_110.jpg
# [141/201] Processed: alpr_lp_117.jpg
# [142/201] Processed: alpr_lp_200.jpg
# [143/201] Processed: alpr_lp_11.jpg
# [144/201] Processed: alpr_lp_63.jpg
# [145/201] Processed: alpr_lp_119.jpg
# [146/201] Processed: alpr_lp_165.jpg
# [147/201] Processed: alpr_lp_18.jpg
# [148/201] Processed: alpr_lp_162.jpg
# [149/201] Processed: alpr_lp_64.jpg
# [150/201] Processed: alpr_lp_147.jpg
# [151/201] Processed: alpr_lp_196.jpg
# [152/201] Processed: alpr_lp_41.jpg
# [153/201] Processed: alpr_lp_90.jpg
# [154/201] Processed: alpr_lp_46.jpg
# [155/201] Processed: alpr_lp_97.jpg
# [156/201] Processed: alpr_lp_140.jpg
# [157/201] Processed: alpr_lp_191.jpg
# [158/201] Processed: alpr_lp_132.jpg
# [159/201] Processed: alpr_lp_48.jpg
# [160/201] Processed: alpr_lp_99.jpg
# [161/201] Processed: alpr_lp_34.jpg
# [162/201] Processed: alpr_lp_149.jpg
# [163/201] Processed: alpr_lp_33.jpg
# [164/201] Processed: alpr_lp_198.jpg
# [165/201] Processed: alpr_lp_135.jpg
# [166/201] Processed: alpr_lp_100.jpg
# [167/201] Processed: alpr_lp_3.jpg
# [168/201] Processed: alpr_lp_107.jpg
# [169/201] Processed: alpr_lp_4.jpg
# [170/201] Processed: alpr_lp_73.jpg
# [171/201] Processed: alpr_lp_109.jpg
# [172/201] Processed: alpr_lp_175.jpg
# [173/201] Processed: alpr_lp_172.jpg
# [174/201] Processed: alpr_lp_74.jpg
# [175/201] Processed: alpr_lp_163.jpg
# [176/201] Processed: alpr_lp_19.jpg
# [177/201] Processed: alpr_lp_65.jpg
# [178/201] Processed: alpr_lp_118.jpg
# [179/201] Processed: alpr_lp_62.jpg
# [180/201] Processed: alpr_lp_164.jpg
# [181/201] Processed: alpr_lp_116.jpg
# [182/201] Processed: alpr_lp_201.jpg
# [183/201] Processed: alpr_lp_10.jpg
# [184/201] Processed: alpr_lp_17.jpg
# [185/201] Processed: alpr_lp_111.jpg
# [186/201] Processed: alpr_lp_189.jpg
# [187/201] Processed: alpr_lp_22.jpg
# [188/201] Processed: alpr_lp_158.jpg
# [189/201] Processed: alpr_lp_124.jpg
# [190/201] Processed: alpr_lp_88.jpg
# [191/201] Processed: alpr_lp_59.jpg
# [192/201] Processed: alpr_lp_123.jpg
# [193/201] Processed: alpr_lp_25.jpg
# [194/201] Processed: alpr_lp_86.jpg
# [195/201] Processed: alpr_lp_57.jpg
# [196/201] Processed: alpr_lp_180.jpg
# [197/201] Processed: alpr_lp_151.jpg
# [198/201] Processed: alpr_lp_187.jpg
# [199/201] Processed: alpr_lp_156.jpg
# [200/201] Processed: alpr_lp_81.jpg
# [201/201] Processed: alpr_lp_50.jpg
#
# Custom parameter processing complete!
